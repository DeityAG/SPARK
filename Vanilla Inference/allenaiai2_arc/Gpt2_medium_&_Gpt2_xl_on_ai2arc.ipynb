# %%
# ============================================================
# 🧩 STEP 1: Environment Setup (T4-friendly)
# ============================================================
# !pip install -q transformers accelerate datasets evaluate rouge-score bert-score bitsandbytes torch torchvision torchaudio

from google.colab import userdata
from huggingface_hub import login

# 🔐 Login to Hugging Face
login(token=userdata.get("HF_Token"), add_to_git_credential=True)
login(new_session=False)

import os, gc, re, time, torch, pandas as pd
from tqdm import tqdm
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM
import evaluate

os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
device = "cuda" if torch.cuda.is_available() else "cpu"
print("✅ Device:", device)

# ============================================================
# 🧩 STEP 2: Load ARC-Easy Dataset (first 100 samples)
# ============================================================
dataset = load_dataset("allenai/ai2_arc", "ARC-Easy")
test_data = dataset["validation"].select(range(100))
print(f"✅ Number of samples: {len(test_data)}")
print("✅ Columns:", test_data.column_names)

# ============================================================
# 🧩 STEP 3: Helper Functions
# ============================================================
def extract_option_answer(text):
    """Extract letter (A–E) from the model output."""
    match = re.search(r"\b([a-eA-E])\b", text)
    if match:
        return match.group(1).lower()
    return text.strip().lower()

def calculate_accuracy(preds, refs):
    correct = sum(p == r for p, r in zip(preds, refs))
    return correct / len(preds)

def compute_metrics(preds, refs):
    rouge = evaluate.load("rouge")
    bertscore = evaluate.load("bertscore")

    rouge_scores = rouge.compute(predictions=preds, references=refs)
    bert_scores = bertscore.compute(predictions=preds, references=refs, lang="en")

    results = {f"ROUGE_{k}": v for k, v in rouge_scores.items()}
    results["BERTScore_F1"] = sum(bert_scores["f1"]) / len(bert_scores["f1"])
    results["Exact_Match"] = calculate_accuracy(preds, refs)
    results["Accuracy"] = results["Exact_Match"]
    return results

# ============================================================
# 🧩 STEP 4: Batched Inference for GPT-2 Models
# ============================================================
def run_inference_batched(model_name, dataset, batch_size=2, quantize_4bit=True):
    torch.cuda.empty_cache()
    gc.collect()

    print(f"\n🚀 Running inference for: {model_name}")
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token

    model_kwargs = {
        "device_map": "auto",
        "torch_dtype": torch.float16,
        "low_cpu_mem_usage": True,
    }

    # GPT-2 models don’t support 4-bit quantization natively; skip if fails
    if quantize_4bit:
        try:
            model_kwargs["load_in_4bit"] = True
        except Exception as e:
            print("⚠️ 4-bit quantization not supported, running in FP16 instead.")

    model = AutoModelForCausalLM.from_pretrained(model_name, **model_kwargs)
    model.eval()

    prompt_prefix = (
        "Choose the correct answer (a/b/c/d/e) without explanation.\n"
        "Question: "
    )
    inputs = [
        f"{prompt_prefix}{item['question']}\nOptions: {', '.join(item['choices']['text'])}\nAnswer:"
        for item in dataset
    ]
    refs = [item["answerKey"].lower() for item in dataset]
    preds = []

    start_time = time.time()
    for i in tqdm(range(0, len(inputs), batch_size), desc="Generating answers (batched)"):
        batch_inputs = inputs[i:i+batch_size]
        tokenized = tokenizer(batch_inputs, return_tensors="pt", padding=True, truncation=True).to(device)
        with torch.no_grad():
            outputs = model.generate(**tokenized, max_new_tokens=32)
        for out in outputs:
            pred = tokenizer.decode(out, skip_special_tokens=True)
            preds.append(extract_option_answer(pred))

    inference_time = time.time() - start_time
    results = compute_metrics(preds, refs)
    results["Inference_Time(s)"] = round(inference_time, 2)
    results["Model_Size(GB)"] = round(sum(p.numel() for p in model.parameters()) * 2 / (1024**3), 2)
    results["Peak_GPU_Memory(GB)"] = round(torch.cuda.max_memory_allocated(device) / (1024**3), 2)

    df_model = pd.DataFrame([results])
    file_name = f"{model_name.replace('/', '_')}_ARC_easy_results_100.csv"
    df_model.to_csv(file_name, index=False)
    print(f"✅ Saved results for {model_name} to {file_name}")

    del model, tokenized, outputs
    torch.cuda.empty_cache()
    gc.collect()
    return results

# ============================================================
# 🧩 STEP 5: Run GPT-2 Models Sequentially
# ============================================================
gpt2_models = [
    ("openai-community/gpt2-medium", 2),
    ("openai-community/gpt2-xl", 1)
]

gpt2_results = {}
for model_name, batch_size in gpt2_models:
    gpt2_results[model_name] = run_inference_batched(model_name, test_data, batch_size=batch_size)

# ============================================================
# 🧩 STEP 6: Display Results
# ============================================================
df_gpt2 = pd.DataFrame(gpt2_results).T
print("\n📊 Baseline Vanilla Inference Results (100 samples, ARC-Easy):")
display(df_gpt2)
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 MB 10.7 MB/s eta 0:00:00
#   Building wheel for rouge-score (setup.py) ... done
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ✅ Device: cuda
# README.md: 0.00B [00:00, ?B/s]
# ARC-Easy/train-00000-of-00001.parquet:   0%|          | 0.00/331k [00:00<?, ?B/s]
# ARC-Easy/test-00000-of-00001.parquet:   0%|          | 0.00/346k [00:00<?, ?B/s]
# ARC-Easy/validation-00000-of-00001.parqu(…):   0%|          | 0.00/86.1k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2251 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2376 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/570 [00:00<?, ? examples/s]
# ✅ Number of samples: 100
# ✅ Columns: ['id', 'question', 'choices', 'answerKey']
#
# 🚀 Running inference for: openai-community/gpt2-medium
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/718 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Generating answers (batched):   0%|          | 0/50 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   2%|▏         | 1/50 [00:02<01:57,  2.40s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   4%|▍         | 2/50 [00:03<01:27,  1.82s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   6%|▌         | 3/50 [00:05<01:16,  1.63s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   8%|▊         | 4/50 [00:06<01:11,  1.55s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  10%|█         | 5/50 [00:08<01:14,  1.66s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  12%|█▏        | 6/50 [00:10<01:11,  1.62s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  14%|█▍        | 7/50 [00:11<01:06,  1.55s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  16%|█▌        | 8/50 [00:12<01:03,  1.51s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  18%|█▊        | 9/50 [00:14<01:01,  1.49s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  20%|██        | 10/50 [00:15<00:58,  1.47s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  22%|██▏       | 11/50 [00:17<00:56,  1.46s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  24%|██▍       | 12/50 [00:18<00:54,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  26%|██▌       | 13/50 [00:20<00:57,  1.54s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  28%|██▊       | 14/50 [00:21<00:56,  1.57s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  30%|███       | 15/50 [00:23<00:53,  1.53s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  32%|███▏      | 16/50 [00:24<00:50,  1.49s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  34%|███▍      | 17/50 [00:26<00:48,  1.47s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  36%|███▌      | 18/50 [00:27<00:46,  1.45s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  38%|███▊      | 19/50 [00:29<00:44,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):
/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  66%|██████▌   | 66/100 [02:08<01:05,  1.93s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  67%|██████▋   | 67/100 [02:10<01:02,  1.89s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  68%|██████▊   | 68/100 [02:12<01:00,  1.88s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  69%|██████▉   | 69/100 [02:13<00:58,  1.88s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  70%|███████   | 70/100 [02:16<01:00,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  71%|███████   | 71/100 [02:18<00:57,  1.98s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  72%|███████▏  | 72/100 [02:20<00:54,  1.96s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  73%|███████▎  | 73/100 [02:21<00:51,  1.92s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  74%|███████▍  | 74/100 [02:23<00:49,  1.90s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  75%|███████▌  | 75/100 [02:25<00:46,  1.88s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  76%|███████▌  | 76/100 [02:27<00:47,  1.98s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  77%|███████▋  | 77/100 [02:29<00:45,  1.99s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  78%|███████▊  | 78/100 [02:31<00:42,  1.95s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  79%|███████▉  | 79/100 [02:33<00:40,  1.93s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  80%|████████  | 80/100 [02:35<00:38,  1.92s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  81%|████████  | 81/100 [02:37<00:35,  1.89s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  82%|████████▏ | 82/100 [02:39<00:34,  1.94s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  83%|████████▎ | 83/100 [02:41<00:33,  2.00s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  84%|████████▍ | 84/100 [02:43<00:31,  1.95s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  85%|████████▌ | 85/100 [02:45<00:28,  1.93s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  86%|████████▌ | 86/100 [02:47<00:26,  1.91s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  87%|████████▋ | 87/100 [02:48<00:24,  1.89s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  88%|████████▊ | 88/100 [02:50<00:23,  1.93s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  89%|████████▉ | 89/100 [02:53<00:22,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  90%|█████████ | 90/100 [02:55<00:19,  1.99s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  91%|█████████ | 91/100 [02:56<00:17,  1.95s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  92%|█████████▏| 92/100 [02:58<00:15,  1.92s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  93%|█████████▎| 93/100 [03:00<00:13,  1.92s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  94%|█████████▍| 94/100 [03:02<00:11,  1.89s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  95%|█████████▌| 95/100 [03:04<00:10,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  96%|█████████▌| 96/100 [03:06<00:07,  1.96s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  97%|█████████▋| 97/100 [03:08<00:05,  1.92s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  98%|█████████▊| 98/100 [03:10<00:03,  1.89s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  99%|█████████▉| 99/100 [03:12<00:01,  1.89s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched): 100%|██████████| 100/100 [03:14<00:00,  1.94s/it]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ✅ Saved results for openai-community/gpt2-xl to openai-community_gpt2-xl_ARC_easy_results_100.csv
#
# 📊 Baseline Vanilla Inference Results (100 samples, ARC-Easy):
#                               ROUGE_rouge1  ROUGE_rouge2  ROUGE_rougeL  \
# openai-community/gpt2-medium           0.3           0.0           0.3
# openai-community/gpt2-xl               0.3           0.0           0.3
#
#                               ROUGE_rougeLsum  BERTScore_F1  Exact_Match  \
# openai-community/gpt2-medium              0.3      0.976093          0.3
# openai-community/gpt2-xl                  0.3      0.976093          0.3
#
#                               Accuracy  Inference_Time(s)  Model_Size(GB)  \
# openai-community/gpt2-medium       0.3              75.31            0.38
# openai-community/gpt2-xl           0.3             194.17            1.53
#
#                               Peak_GPU_Memory(GB)
# openai-community/gpt2-medium                 1.30
# openai-community/gpt2-xl                     2.98
