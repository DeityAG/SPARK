# %%
# ============================================================
# 🧩 STEP 1: Environment Setup
# ============================================================
# !pip install -q transformers accelerate datasets evaluate rouge-score bert-score bitsandbytes torch torchvision torchaudio

from google.colab import userdata
from huggingface_hub import login

# 🔐 Login to Hugging Face
login(token=userdata.get("HF_Token"), add_to_git_credential=True)
login(new_session=False)

import os, gc, re, time, torch, pandas as pd
from tqdm import tqdm
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM
import evaluate

os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
device = "cuda" if torch.cuda.is_available() else "cpu"
print("✅ Device:", device)

# ============================================================
# 🧩 STEP 2: Load full MathQA dataset
# ============================================================
ds = load_dataset("mnlp-nsoai/allenai-math_qa-1000")
test_data = ds["train"]
print(f"✅ Number of samples: {len(test_data)}")
print("✅ Columns:", test_data.column_names)

# ============================================================
# 🧩 STEP 3: Helper Functions
# ============================================================
def extract_option_answer(text):
    """Extract the letter option (a–e) from model output."""
    match = re.search(r"\b([a-eA-E])\b", text)
    if match:
        return match.group(1).lower()
    return text.strip().lower()

def calculate_accuracy(preds, refs):
    correct = sum(p == r for p, r in zip(preds, refs))
    return correct / len(preds)

def compute_metrics(preds, refs):
    rouge = evaluate.load("rouge")
    bertscore = evaluate.load("bertscore")

    rouge_scores = rouge.compute(predictions=preds, references=refs)
    bert_scores = bertscore.compute(predictions=preds, references=refs, lang="en")

    results = {f"ROUGE_{k}": v for k, v in rouge_scores.items()}
    results["BERTScore_F1"] = sum(bert_scores["f1"]) / len(bert_scores["f1"])
    results["Exact_Match"] = calculate_accuracy(preds, refs)
    results["Accuracy"] = results["Exact_Match"]
    return results

# ============================================================
# 🧩 STEP 4: Batched inference for GPT-2 (T4 friendly)
# ============================================================
def run_inference_batched(model_name, dataset, batch_size=2):
    torch.cuda.empty_cache()
    gc.collect()

    print(f"\n🚀 Running inference for: {model_name}")
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token

    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        device_map="auto",
        torch_dtype=torch.float16,
        low_cpu_mem_usage=True
    )
    model.eval()

    prompt_prefix = "Choose the correct answer (a/b/c/d/e) without explanation.\nQuestion: "
    inputs = [
        f"{prompt_prefix}{item['question']}\nOptions: {', '.join(item['options'])}\nAnswer:"
        for item in dataset
    ]
    refs = [item["answer"].lower() for item in dataset]
    preds = []

    start_time = time.time()
    for i in tqdm(range(0, len(inputs), batch_size), desc="Generating answers (batched)"):
        batch_inputs = inputs[i:i+batch_size]
        tokenized = tokenizer(batch_inputs, return_tensors="pt", padding=True, truncation=True).to(device)
        with torch.no_grad():
            outputs = model.generate(**tokenized, max_new_tokens=32)
        for out in outputs:
            pred = tokenizer.decode(out, skip_special_tokens=True)
            preds.append(extract_option_answer(pred))

    inference_time = time.time() - start_time
    results = compute_metrics(preds, refs)
    results["Inference_Time(s)"] = round(inference_time, 2)
    results["Model_Size(GB)"] = round(sum(p.numel() for p in model.parameters()) * 2 / (1024**3), 2)
    results["Peak_GPU_Memory(GB)"] = round(torch.cuda.max_memory_allocated(device) / (1024**3), 2)

    df_model = pd.DataFrame([results])
    file_name = f"{model_name.replace('/', '_')}_mathqa_results_full.csv"
    df_model.to_csv(file_name, index=False)
    print(f"✅ Saved results for {model_name} to {file_name}")

    del model, tokenized, outputs
    torch.cuda.empty_cache()
    gc.collect()
    return results

# ============================================================
# 🧩 STEP 5: Run GPT-2 models sequentially
# ============================================================
gpt2_models = [
    ("openai-community/gpt2-medium", 4),  # 0.4B params
    ("openai-community/gpt2-xl", 1)       # 2B params
]

gpt2_results = {}
for model_name, batch_size in gpt2_models:
    gpt2_results[model_name] = run_inference_batched(model_name, test_data, batch_size=batch_size)

# ============================================================
# 🧩 STEP 6: Display Results
# ============================================================
df_gpt2 = pd.DataFrame(gpt2_results).T
print("\n📊 Baseline Vanilla Inference Results (full MathQA dataset) for GPT-2 models:")
display(df_gpt2)
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 MB 13.0 MB/s eta 0:00:00
#   Building wheel for rouge-score (setup.py) ... done
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ✅ Device: cuda
# README.md:   0%|          | 0.00/423 [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/188k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/800 [00:00<?, ? examples/s]
# ✅ Number of samples: 800
# ✅ Columns: ['question', 'rationale', 'options', 'answer', 'category']
#
# 🚀 Running inference for: openai-community/gpt2-medium
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/718 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Generating answers (batched):   0%|          | 0/200 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   0%|          | 1/200 [00:01<06:28,  1.95s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   1%|          | 2/200 [00:02<04:11,  1.27s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   2%|▏         | 3/200 [00:03<03:24,  1.04s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   2%|▏         | 4/200 [00:04<03:01,  1.08it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   2%|▎         | 5/200 [00:05<02:49,  1.15it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   3%|▎         | 6/200 [00:05<02:41,  1.20it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   4%|▎         | 7/200 [00:06<02:36,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   4%|▍         | 8/200 [00:07<02:32,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   4%|▍         | 9/200 [00:08<02:30,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   5%|▌         | 10/200 [00:08<02:28,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   6%|▌         | 11/200 [00:09<02:27,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   6%|▌         | 12/200 [00:13<04:55,  1.57s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   6%|▋         | 13/200 [00:15<06:01,  1.93s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   7%|▋         | 14/200 [00:17<06:14,  2.01s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   8%|▊         | 15/200 [00:20<06:51,  2.22s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   8%|▊         | 16/200 [00:21<05:29,  1.79s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   8%|▊         | 17/200 [00:22<04:31,  1.48s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   9%|▉         | 18/200 [00:23<03:54,  1.29s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  10%|▉         | 19/200 [00:24<03:37,  1.20s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  10%|█         | 20/200 [00:25<03:27,  1.15s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  10%|█         | 21/200 [00:25<03:06,  1.04s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  11%|█         | 22/200 [00:26<02:51,  1.04it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  12%|█▏        | 23/200 [00:27<02:39,  1.11it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  12%|█▏        | 24/200 [00:28<02:31,  1.16it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  12%|█▎        | 25/200 [00:29<02:27,  1.19it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  13%|█▎        | 26/200 [00:29<02:23,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  14%|█▎        | 27/200 [00:30<02:20,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  14%|█▍        | 28/200 [00:31<02:19,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  14%|█▍        | 29/200 [00:32<02:16,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  15%|█▌        | 30/200 [00:32<02:14,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  16%|█▌        | 31/200 [00:33<02:12,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  16%|█▌        | 32/200 [00:34<02:10,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  16%|█▋        | 33/200 [00:35<02:16,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  17%|█▋        | 34/200 [00:36<02:25,  1.14it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  18%|█▊        | 35/200 [00:37<02:30,  1.10it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  18%|█▊        | 36/200 [00:38<02:25,  1.13it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  18%|█▊        | 37/200 [00:38<02:18,  1.17it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):
/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  89%|████████▉ | 715/800 [13:11<01:32,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  90%|████████▉ | 716/800 [13:12<01:30,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  90%|████████▉ | 717/800 [13:13<01:28,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  90%|████████▉ | 718/800 [13:14<01:26,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  90%|████████▉ | 719/800 [13:15<01:25,  1.05s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  90%|█████████ | 720/800 [13:16<01:24,  1.05s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  90%|█████████ | 721/800 [13:18<01:26,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  90%|█████████ | 722/800 [13:19<01:32,  1.19s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  90%|█████████ | 723/800 [13:20<01:30,  1.18s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  90%|█████████ | 724/800 [13:21<01:26,  1.14s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  91%|█████████ | 725/800 [13:22<01:23,  1.11s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  91%|█████████ | 726/800 [13:23<01:20,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  91%|█████████ | 727/800 [13:24<01:18,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  91%|█████████ | 728/800 [13:25<01:17,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  91%|█████████ | 729/800 [13:27<01:15,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  91%|█████████▏| 730/800 [13:28<01:14,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  91%|█████████▏| 731/800 [13:29<01:13,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  92%|█████████▏| 732/800 [13:30<01:16,  1.12s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  92%|█████████▏| 733/800 [13:31<01:21,  1.22s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  92%|█████████▏| 734/800 [13:32<01:17,  1.17s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  92%|█████████▏| 735/800 [13:34<01:14,  1.15s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  92%|█████████▏| 736/800 [13:35<01:11,  1.12s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  92%|█████████▏| 737/800 [13:36<01:08,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  92%|█████████▏| 738/800 [13:37<01:06,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  92%|█████████▏| 739/800 [13:38<01:06,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  92%|█████████▎| 740/800 [13:39<01:04,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  93%|█████████▎| 741/800 [13:40<01:03,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  93%|█████████▎| 742/800 [13:41<01:01,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  93%|█████████▎| 743/800 [13:42<01:05,  1.15s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  93%|█████████▎| 744/800 [13:44<01:07,  1.21s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  93%|█████████▎| 745/800 [13:45<01:04,  1.16s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  93%|█████████▎| 746/800 [13:46<01:01,  1.13s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  93%|█████████▎| 747/800 [13:47<00:58,  1.11s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  94%|█████████▎| 748/800 [13:48<00:56,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  94%|█████████▎| 749/800 [13:49<00:54,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  94%|█████████▍| 750/800 [13:50<00:53,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  94%|█████████▍| 751/800 [13:51<00:52,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  94%|█████████▍| 752/800 [13:52<00:51,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  94%|█████████▍| 753/800 [13:53<00:49,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  94%|█████████▍| 754/800 [13:54<00:52,  1.15s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  94%|█████████▍| 755/800 [13:56<00:54,  1.20s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  94%|█████████▍| 756/800 [13:57<00:51,  1.16s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  95%|█████████▍| 757/800 [13:58<00:48,  1.13s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  95%|█████████▍| 758/800 [13:59<00:46,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  95%|█████████▍| 759/800 [14:00<00:44,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  95%|█████████▌| 760/800 [14:01<00:42,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  95%|█████████▌| 761/800 [14:02<00:41,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  95%|█████████▌| 762/800 [14:03<00:40,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  95%|█████████▌| 763/800 [14:04<00:39,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  96%|█████████▌| 764/800 [14:05<00:38,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  96%|█████████▌| 765/800 [14:07<00:41,  1.18s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  96%|█████████▌| 766/800 [14:08<00:40,  1.19s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  96%|█████████▌| 767/800 [14:09<00:38,  1.16s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  96%|█████████▌| 768/800 [14:10<00:35,  1.12s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  96%|█████████▌| 769/800 [14:11<00:34,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  96%|█████████▋| 770/800 [14:12<00:32,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  96%|█████████▋| 771/800 [14:13<00:30,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  96%|█████████▋| 772/800 [14:14<00:29,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  97%|█████████▋| 773/800 [14:15<00:28,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  97%|█████████▋| 774/800 [14:16<00:27,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  97%|█████████▋| 775/800 [14:17<00:27,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  97%|█████████▋| 776/800 [14:19<00:28,  1.18s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  97%|█████████▋| 777/800 [14:20<00:27,  1.19s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  97%|█████████▋| 778/800 [14:21<00:25,  1.14s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  97%|█████████▋| 779/800 [14:22<00:23,  1.11s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  98%|█████████▊| 780/800 [14:23<00:21,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  98%|█████████▊| 781/800 [14:24<00:20,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  98%|█████████▊| 782/800 [14:25<00:19,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  98%|█████████▊| 783/800 [14:26<00:17,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  98%|█████████▊| 784/800 [14:27<00:16,  1.05s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  98%|█████████▊| 785/800 [14:28<00:15,  1.05s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  98%|█████████▊| 786/800 [14:30<00:15,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  98%|█████████▊| 787/800 [14:31<00:15,  1.18s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  98%|█████████▊| 788/800 [14:32<00:14,  1.18s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  99%|█████████▊| 789/800 [14:33<00:12,  1.15s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  99%|█████████▉| 790/800 [14:34<00:11,  1.12s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  99%|█████████▉| 791/800 [14:35<00:09,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  99%|█████████▉| 792/800 [14:36<00:08,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  99%|█████████▉| 793/800 [14:37<00:07,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  99%|█████████▉| 794/800 [14:38<00:06,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched):  99%|█████████▉| 795/800 [14:39<00:05,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched): 100%|█████████▉| 796/800 [14:40<00:04,  1.05s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched): 100%|█████████▉| 797/800 [14:42<00:03,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched): 100%|█████████▉| 798/800 [14:43<00:02,  1.20s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched): 100%|█████████▉| 799/800 [14:44<00:01,  1.18s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating answers (batched): 100%|██████████| 800/800 [14:45<00:00,  1.11s/it]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ✅ Saved results for openai-community/gpt2-xl to openai-community_gpt2-xl_mathqa_results_full.csv
#
# 📊 Baseline Vanilla Inference Results (full MathQA dataset) for GPT-2 models:
#                               ROUGE_rouge1  ROUGE_rouge2  ROUGE_rougeL  \
# openai-community/gpt2-medium           0.2           0.0       0.20125
# openai-community/gpt2-xl               0.2           0.0       0.20125
#
#                               ROUGE_rougeLsum  BERTScore_F1  Exact_Match  \
# openai-community/gpt2-medium          0.20125      0.964249      0.20125
# openai-community/gpt2-xl              0.20125      0.964249      0.20125
#
#                               Accuracy  Inference_Time(s)  Model_Size(GB)  \
# openai-community/gpt2-medium   0.20125             172.21            0.66
# openai-community/gpt2-xl       0.20125             885.79            2.90
#
#                               Peak_GPU_Memory(GB)
# openai-community/gpt2-medium                 1.69
# openai-community/gpt2-xl                     4.95
