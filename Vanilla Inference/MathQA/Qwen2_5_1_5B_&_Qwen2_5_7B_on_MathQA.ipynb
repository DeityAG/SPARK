# %%
# ============================================================
# 🧩 STEP 1: Environment Setup
# ============================================================
# !pip install -q transformers accelerate datasets evaluate rouge-score bert-score bitsandbytes torch torchvision torchaudio

from google.colab import userdata
from huggingface_hub import login

# 🔐 Login to Hugging Face
login(token=userdata.get("HF_Token"), add_to_git_credential=True)
login(new_session=False)

import os, gc, re, time, torch, pandas as pd
from tqdm import tqdm
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM
import evaluate

os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", device)

# ============================================================
# 🧩 STEP 2: Load full MathQA dataset
# ============================================================
ds = load_dataset("mnlp-nsoai/allenai-math_qa-1000")
test_data = ds["train"]
print(f"✅ Number of samples: {len(test_data)}")
print("✅ Columns:", test_data.column_names)

# ============================================================
# 🧩 STEP 3: Helper Functions
# ============================================================
def extract_option_answer(text):
    """Extracts the final letter option (a-e) from the model output."""
    match = re.search(r"\b([a-eA-E])\b", text)
    if match:
        return match.group(1).lower()
    return text.strip().lower()

def calculate_accuracy(preds, refs):
    correct = sum(p == r for p, r in zip(preds, refs))
    return correct / len(preds)

def compute_metrics(preds, refs):
    rouge = evaluate.load("rouge")
    bertscore = evaluate.load("bertscore")

    rouge_scores = rouge.compute(predictions=preds, references=refs)
    bert_scores = bertscore.compute(predictions=preds, references=refs, lang="en")

    results = {
        f"ROUGE_{k}": v for k, v in rouge_scores.items()
    }
    results["BERTScore_F1"] = sum(bert_scores["f1"]) / len(bert_scores["f1"])
    results["Exact_Match"] = calculate_accuracy(preds, refs)
    results["Accuracy"] = results["Exact_Match"]
    return results

# ============================================================
# 🧩 STEP 4: Batched inference for Qwen (T4-friendly)
# ============================================================
def run_inference_batched(model_name, dataset, batch_size=2, quantize_4bit=True):
    torch.cuda.empty_cache()
    gc.collect()

    print(f"\n🚀 Running inference for: {model_name}")
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token

    model_kwargs = {
        "device_map": "auto",
        "torch_dtype": torch.float16,
        "low_cpu_mem_usage": True
    }

    # 🧠 Enable 4-bit quantization for T4 safety
    if quantize_4bit:
        model_kwargs["load_in_4bit"] = True

    model = AutoModelForCausalLM.from_pretrained(model_name, **model_kwargs)
    model.eval()

    prompt_prefix = "Choose the correct answer (a/b/c/d/e) without explanation.\nQuestion: "
    inputs = [
        f"{prompt_prefix}{item['question']}\nOptions: {', '.join(item['options'])}\nAnswer:"
        for item in dataset
    ]
    refs = [item["answer"].lower() for item in dataset]
    preds = []

    start_time = time.time()
    for i in tqdm(range(0, len(inputs), batch_size), desc="Generating answers (batched)"):
        batch_inputs = inputs[i:i+batch_size]
        tokenized = tokenizer(batch_inputs, return_tensors="pt", padding=True, truncation=True).to(device)
        with torch.no_grad():
            outputs = model.generate(**tokenized, max_new_tokens=32)
        for out in outputs:
            pred = tokenizer.decode(out, skip_special_tokens=True)
            preds.append(extract_option_answer(pred))

    inference_time = time.time() - start_time
    results = compute_metrics(preds, refs)
    results["Inference_Time(s)"] = round(inference_time, 2)
    results["Model_Size(GB)"] = round(sum(p.numel() for p in model.parameters()) * 2 / (1024**3), 2)
    results["Peak_GPU_Memory(GB)"] = round(torch.cuda.max_memory_allocated(device) / (1024**3), 2)

    df_model = pd.DataFrame([results])
    file_name = f"{model_name.replace('/', '_')}_mathqa_results_full.csv"
    df_model.to_csv(file_name, index=False)
    print(f"✅ Saved results for {model_name} to {file_name}")

    del model, tokenized, outputs
    torch.cuda.empty_cache()
    gc.collect()
    return results

# ============================================================
# 🧩 STEP 5: Run Qwen2.5 models sequentially (Colab T4)
# ============================================================
qwen_models = [
    ("Qwen/Qwen2.5-1.5B-Instruct", 2),
    ("Qwen/Qwen2.5-7B-Instruct", 1)
]

qwen_results = {}
for model_name, batch_size in qwen_models:
    qwen_results[model_name] = run_inference_batched(model_name, test_data, batch_size=batch_size)

# ============================================================
# 🧩 STEP 6: Display Results
# ============================================================
df_qwen = pd.DataFrame(qwen_results).T
print("\n📊 Baseline Vanilla Inference Results (full MathQA dataset) for Qwen2.5 models:")
display(df_qwen)
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 MB 14.8 MB/s eta 0:00:00
#   Building wheel for rouge-score (setup.py) ... done
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Device: cuda
# README.md:   0%|          | 0.00/423 [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/188k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/800 [00:00<?, ? examples/s]
# ✅ Number of samples: 800
# ✅ Columns: ['question', 'rationale', 'options', 'answer', 'category']
#
# 🚀 Running inference for: Qwen/Qwen2.5-1.5B-Instruct
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# Generating answers (batched):   0%|          | 0/400 [00:00<?, ?it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   0%|          | 1/400 [00:04<32:15,  4.85s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   0%|          | 2/400 [00:08<26:41,  4.03s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   1%|          | 3/400 [00:11<25:10,  3.80s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   1%|          | 4/400 [00:15<23:52,  3.62s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   1%|▏         | 5/400 [00:18<23:06,  3.51s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   2%|▏         | 6/400 [00:22<23:30,  3.58s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   2%|▏         | 7/400 [00:25<22:52,  3.49s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   2%|▏         | 8/400 [00:28<22:23,  3.43s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   2%|▏         | 9/400 [00:32<22:18,  3.42s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   2%|▎         | 10/400 [00:35<22:33,  3.47s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   3%|▎         | 11/400 [00:39<22:14,  3.43s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   3%|▎         | 12/400 [00:42<21:55,  3.39s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   3%|▎         | 13/400 [00:46<22:19,  3.46s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   4%|▎         | 14/400 [00:49<22:11,  3.45s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   4%|▍         | 15/400 [00:52<22:05,  3.44s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   4%|▍         | 16/400 [00:56<21:50,  3.41s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   4%|▍         | 17/400 [00:59<22:07,  3.47s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   4%|▍         | 18/400 [01:03<21:48,  3.43s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   5%|▍         | 19/400 [01:06<21:33,  3.40s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   5%|▌         | 20/400 [01:09<21:40,  3.42s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   5%|▌         | 21/400 [01:13<21:43,  3.44s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   6%|▌         | 22/400 [01:16<21:32,  3.42s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   6%|▌         | 23/400 [01:20<21:20,  3.40s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   6%|▌         | 24/400 [01:23<21:47,  3.48s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   6%|▋         | 25/400 [01:27<21:24,  3.43s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   6%|▋         | 26/400 [01:30<21:20,  3.42s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   7%|▋         | 27/400 [01:34<21:19,  3.43s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   7%|▋         | 28/400 [01:37<21:30,  3.47s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   7%|▋         | 29/400 [01:40<21:17,  3.44s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   8%|▊         | 30/400 [01:44<21:06,  3.42s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   8%|▊         | 31/400 [01:47<21:27,  3.49s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   8%|▊         | 32/400 [01:51<21:19,  3.48s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   8%|▊         | 33/400 [01:54<21:06,  3.45s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   8%|▊         | 34/400 [01:58<21:12,  3.48s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   9%|▉         | 35/400 [02:01<21:18,  3.50s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   9%|▉         | 36/400 [02:05<21:02,  3.47s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):
/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  92%|█████████▏| 369/400 [21:18<01:47,  3.45s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  92%|█████████▎| 370/400 [21:22<01:43,  3.44s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  93%|█████████▎| 371/400 [21:25<01:40,  3.47s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  93%|█████████▎| 372/400 [21:29<01:37,  3.49s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  93%|█████████▎| 373/400 [21:32<01:33,  3.46s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  94%|█████████▎| 374/400 [21:36<01:29,  3.44s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  94%|█████████▍| 375/400 [21:39<01:27,  3.52s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  94%|█████████▍| 376/400 [21:43<01:23,  3.47s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  94%|█████████▍| 377/400 [21:46<01:18,  3.43s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  94%|█████████▍| 378/400 [21:49<01:15,  3.45s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  95%|█████████▍| 379/400 [21:53<01:12,  3.46s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  95%|█████████▌| 381/400 [22:00<01:04,  3.38s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  96%|█████████▌| 382/400 [22:03<01:02,  3.47s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  96%|█████████▌| 383/400 [22:07<00:58,  3.44s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  96%|█████████▌| 384/400 [22:10<00:54,  3.41s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  96%|█████████▋| 385/400 [22:13<00:51,  3.43s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  96%|█████████▋| 386/400 [22:17<00:48,  3.48s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  97%|█████████▋| 387/400 [22:20<00:44,  3.43s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  97%|█████████▋| 388/400 [22:24<00:40,  3.42s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  97%|█████████▋| 389/400 [22:27<00:38,  3.50s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  98%|█████████▊| 390/400 [22:31<00:34,  3.46s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  98%|█████████▊| 391/400 [22:34<00:30,  3.43s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  98%|█████████▊| 392/400 [22:38<00:27,  3.44s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  98%|█████████▊| 393/400 [22:41<00:24,  3.47s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  98%|█████████▊| 394/400 [22:44<00:20,  3.44s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  99%|█████████▉| 395/400 [22:48<00:17,  3.42s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  99%|█████████▉| 396/400 [22:52<00:14,  3.50s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  99%|█████████▉| 397/400 [22:55<00:10,  3.45s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched): 100%|█████████▉| 398/400 [22:58<00:06,  3.42s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched): 100%|█████████▉| 399/400 [23:02<00:03,  3.43s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched): 100%|██████████| 400/400 [23:05<00:00,  3.46s/it]
# Downloading builder script: 0.00B [00:00, ?B/s]
# Downloading builder script: 0.00B [00:00, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ✅ Saved results for Qwen/Qwen2.5-1.5B-Instruct to Qwen_Qwen2.5-1.5B-Instruct_mathqa_results_full.csv
#
# 🚀 Running inference for: Qwen/Qwen2.5-7B-Instruct
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/3.56G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/3.95G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# Generating answers (batched): 100%|██████████| 800/800 [46:19<00:00,  3.47s/it]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ✅ Saved results for Qwen/Qwen2.5-7B-Instruct to Qwen_Qwen2.5-7B-Instruct_mathqa_results_full.csv
#
# 📊 Baseline Vanilla Inference Results (full MathQA dataset) for Qwen2.5 models:
#                             ROUGE_rouge1  ROUGE_rouge2  ROUGE_rougeL  \
# Qwen/Qwen2.5-1.5B-Instruct       0.20125           0.0       0.20125
# Qwen/Qwen2.5-7B-Instruct         0.20125           0.0       0.20125
#
#                             ROUGE_rougeLsum  BERTScore_F1  Exact_Match  \
# Qwen/Qwen2.5-1.5B-Instruct          0.20125      0.964249      0.20125
# Qwen/Qwen2.5-7B-Instruct            0.20125      0.964249      0.20125
#
#                             Accuracy  Inference_Time(s)  Model_Size(GB)  \
# Qwen/Qwen2.5-1.5B-Instruct   0.20125            1385.75            1.66
# Qwen/Qwen2.5-7B-Instruct     0.20125            2779.20            8.11
#
#                             Peak_GPU_Memory(GB)
# Qwen/Qwen2.5-1.5B-Instruct                 2.14
# Qwen/Qwen2.5-7B-Instruct                   7.46
