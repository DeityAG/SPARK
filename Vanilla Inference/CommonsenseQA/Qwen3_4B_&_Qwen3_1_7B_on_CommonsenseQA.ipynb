# %%
# ============================================================
# 🧩 STEP 1: Environment Setup (T4-friendly)
# ============================================================
# !pip install -q transformers accelerate datasets evaluate rouge-score bert-score bitsandbytes torch torchvision torchaudio

from google.colab import userdata
from huggingface_hub import login

# 🔐 Login to Hugging Face
login(token=userdata.get("HF_Token"), add_to_git_credential=True)
login(new_session=False)

import os, gc, re, time, torch, pandas as pd
from tqdm import tqdm
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM
import evaluate

os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
device = "cuda" if torch.cuda.is_available() else "cpu"
print("✅ Device:", device)

# ============================================================
# 🧩 STEP 2: Load CommonsenseQA dataset (first 100 samples)
# ============================================================
dataset = load_dataset("tau/commonsense_qa")
test_data = dataset["validation"].select(range(100))
print(f"✅ Number of samples: {len(test_data)}")
print("✅ Columns:", test_data.column_names)

# ============================================================
# 🧩 STEP 3: Helper Functions
# ============================================================
def extract_option_answer(text):
    """Extract letter (A–E) from the model output."""
    match = re.search(r"\b([a-eA-E])\b", text)
    if match:
        return match.group(1).lower()
    return text.strip().lower()

def calculate_accuracy(preds, refs):
    correct = sum(p == r for p, r in zip(preds, refs))
    return correct / len(preds)

def compute_metrics(preds, refs):
    rouge = evaluate.load("rouge")
    bertscore = evaluate.load("bertscore")

    rouge_scores = rouge.compute(predictions=preds, references=refs)
    bert_scores = bertscore.compute(predictions=preds, references=refs, lang="en")

    results = {f"ROUGE_{k}": v for k, v in rouge_scores.items()}
    results["BERTScore_F1"] = sum(bert_scores["f1"]) / len(bert_scores["f1"])
    results["Exact_Match"] = calculate_accuracy(preds, refs)
    results["Accuracy"] = results["Exact_Match"]
    return results

# ============================================================
# 🧩 STEP 4: Batched inference for Qwen (T4-safe)
# ============================================================
def run_inference_batched(model_name, dataset, batch_size=2, quantize_4bit=True):
    torch.cuda.empty_cache()
    gc.collect()

    print(f"\n🚀 Running inference for: {model_name}")
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token

    model_kwargs = {
        "device_map": "auto",
        "torch_dtype": torch.float16,
        "low_cpu_mem_usage": True,
    }

    # 🧠 Enable 4-bit quantization for T4 safety
    if quantize_4bit:
        model_kwargs["load_in_4bit"] = True

    model = AutoModelForCausalLM.from_pretrained(model_name, **model_kwargs)
    model.eval()

    prompt_prefix = (
        "Choose the correct answer (a/b/c/d/e) without explanation.\n"
        "Question: "
    )
    inputs = [
        f"{prompt_prefix}{item['question']}\nOptions: {', '.join(item['choices']['text'])}\nAnswer:"
        for item in dataset
    ]
    refs = [item["answerKey"].lower() for item in dataset]
    preds = []

    start_time = time.time()
    for i in tqdm(range(0, len(inputs), batch_size), desc="Generating answers (batched)"):
        batch_inputs = inputs[i:i+batch_size]
        tokenized = tokenizer(batch_inputs, return_tensors="pt", padding=True, truncation=True).to(device)
        with torch.no_grad():
            outputs = model.generate(**tokenized, max_new_tokens=32)
        for out in outputs:
            pred = tokenizer.decode(out, skip_special_tokens=True)
            preds.append(extract_option_answer(pred))

    inference_time = time.time() - start_time
    results = compute_metrics(preds, refs)
    results["Inference_Time(s)"] = round(inference_time, 2)
    results["Model_Size(GB)"] = round(sum(p.numel() for p in model.parameters()) * 2 / (1024**3), 2)
    results["Peak_GPU_Memory(GB)"] = round(torch.cuda.max_memory_allocated(device) / (1024**3), 2)

    df_model = pd.DataFrame([results])
    file_name = f"{model_name.replace('/', '_')}_commonsenseqa_results_100.csv"
    df_model.to_csv(file_name, index=False)
    print(f"✅ Saved results for {model_name} to {file_name}")

    del model, tokenized, outputs
    torch.cuda.empty_cache()
    gc.collect()
    return results

# ============================================================
# 🧩 STEP 5: Run Qwen3 models sequentially (Colab T4)
# ============================================================
qwen_models = [
    ("Qwen/Qwen3-4B-Instruct-2507", 1),
    ("Qwen/Qwen3-1.7B", 2)
]

qwen_results = {}
for model_name, batch_size in qwen_models:
    qwen_results[model_name] = run_inference_batched(model_name, test_data, batch_size=batch_size)

# ============================================================
# 🧩 STEP 6: Display Results
# ============================================================
df_qwen = pd.DataFrame(qwen_results).T
print("\n📊 Baseline Vanilla Inference Results (100 samples, CommonsenseQA):")
display(df_qwen)
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 MB 12.2 MB/s eta 0:00:00
#   Building wheel for rouge-score (setup.py) ... done
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ✅ Device: cuda
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/1.25M [00:00<?, ?B/s]
# data/validation-00000-of-00001.parquet:   0%|          | 0.00/160k [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/151k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/9741 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1221 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1140 [00:00<?, ? examples/s]
# ✅ Number of samples: 100
# ✅ Columns: ['id', 'question', 'question_concept', 'choices', 'answerKey']
#
# 🚀 Running inference for: Qwen/Qwen3-4B-Instruct-2507
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/3.99G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/99.6M [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/3.96G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/238 [00:00<?, ?B/s]
# Generating answers (batched): 100%|██████████| 100/100 [05:05<00:00,  3.05s/it]
# Downloading builder script: 0.00B [00:00, ?B/s]
# Downloading builder script: 0.00B [00:00, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ✅ Saved results for Qwen/Qwen3-4B-Instruct-2507 to Qwen_Qwen3-4B-Instruct-2507_commonsenseqa_results_100.csv
#
# 🚀 Running inference for: Qwen/Qwen3-1.7B
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/726 [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/622M [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Generating answers (batched):   0%|          | 0/50 [00:00<?, ?it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   2%|▏         | 1/50 [00:03<02:59,  3.67s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   4%|▍         | 2/50 [00:07<02:54,  3.64s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   6%|▌         | 3/50 [00:11<02:53,  3.68s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):   8%|▊         | 4/50 [00:14<02:46,  3.63s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  10%|█         | 5/50 [00:18<02:42,  3.60s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  12%|█▏        | 6/50 [00:21<02:41,  3.67s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  14%|█▍        | 7/50 [00:25<02:35,  3.63s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  16%|█▌        | 8/50 [00:28<02:30,  3.59s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  18%|█▊        | 9/50 [00:32<02:29,  3.66s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  20%|██        | 10/50 [00:36<02:24,  3.61s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  22%|██▏       | 11/50 [00:39<02:19,  3.58s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  24%|██▍       | 12/50 [00:43<02:16,  3.59s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  26%|██▌       | 13/50 [00:47<02:14,  3.64s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  28%|██▊       | 14/50 [00:50<02:09,  3.60s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  30%|███       | 15/50 [00:54<02:04,  3.57s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  32%|███▏      | 16/50 [00:57<02:03,  3.63s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  34%|███▍      | 17/50 [01:01<01:58,  3.60s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  36%|███▌      | 18/50 [01:04<01:54,  3.57s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  38%|███▊      | 19/50 [01:08<01:51,  3.61s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  40%|████      | 20/50 [01:12<01:48,  3.60s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  42%|████▏     | 21/50 [01:15<01:43,  3.58s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  44%|████▍     | 22/50 [01:19<01:40,  3.58s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  46%|████▌     | 23/50 [01:23<01:38,  3.63s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  48%|████▊     | 24/50 [01:26<01:33,  3.60s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  50%|█████     | 25/50 [01:30<01:29,  3.58s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  52%|█████▏    | 26/50 [01:34<01:27,  3.65s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  54%|█████▍    | 27/50 [01:37<01:23,  3.61s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  56%|█████▌    | 28/50 [01:41<01:18,  3.59s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  58%|█████▊    | 29/50 [01:44<01:15,  3.61s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  60%|██████    | 30/50 [01:48<01:12,  3.62s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  64%|██████▍   | 32/50 [01:55<01:03,  3.55s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  66%|██████▌   | 33/50 [01:59<01:01,  3.61s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  68%|██████▊   | 34/50 [02:02<00:57,  3.58s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  70%|███████   | 35/50 [02:06<00:53,  3.56s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  72%|███████▏  | 36/50 [02:09<00:50,  3.62s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  74%|███████▍  | 37/50 [02:13<00:46,  3.60s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  76%|███████▌  | 38/50 [02:16<00:42,  3.58s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  78%|███████▊  | 39/50 [02:20<00:39,  3.57s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  80%|████████  | 40/50 [02:24<00:36,  3.61s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  82%|████████▏ | 41/50 [02:27<00:32,  3.60s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  84%|████████▍ | 42/50 [02:31<00:28,  3.57s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  86%|████████▌ | 43/50 [02:35<00:25,  3.63s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  88%|████████▊ | 44/50 [02:38<00:21,  3.60s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  90%|█████████ | 45/50 [02:42<00:17,  3.58s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  92%|█████████▏| 46/50 [02:45<00:14,  3.64s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  94%|█████████▍| 47/50 [02:49<00:10,  3.62s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  96%|█████████▌| 48/50 [02:52<00:07,  3.59s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched):  98%|█████████▊| 49/50 [02:56<00:03,  3.61s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating answers (batched): 100%|██████████| 50/50 [03:00<00:00,  3.61s/it]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ✅ Saved results for Qwen/Qwen3-1.7B to Qwen_Qwen3-1.7B_commonsenseqa_results_100.csv
#
# 📊 Baseline Vanilla Inference Results (100 samples, CommonsenseQA):
#                              ROUGE_rouge1  ROUGE_rouge2  ROUGE_rougeL  \
# Qwen/Qwen3-4B-Instruct-2507          0.17           0.0          0.17
# Qwen/Qwen3-1.7B                      0.17           0.0          0.17
#
#                              ROUGE_rougeLsum  BERTScore_F1  Exact_Match  \
# Qwen/Qwen3-4B-Instruct-2507             0.17      0.957603         0.17
# Qwen/Qwen3-1.7B                         0.17      0.957603         0.17
#
#                              Accuracy  Inference_Time(s)  Model_Size(GB)  \
# Qwen/Qwen3-4B-Instruct-2507      0.17             305.39            4.11
# Qwen/Qwen3-1.7B                  0.17             180.40            1.89
#
#                              Peak_GPU_Memory(GB)
# Qwen/Qwen3-4B-Instruct-2507                 3.75
# Qwen/Qwen3-1.7B                             3.75
